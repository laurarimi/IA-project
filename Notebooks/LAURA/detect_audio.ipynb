# %%
# !pip install webrtcvad
# Out:
# Collecting webrtcvad
#   Using cached webrtcvad-2.0.10.tar.gz (66 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: webrtcvad
#   Building wheel for webrtcvad (setup.py): started
#   Building wheel for webrtcvad (setup.py): finished with status 'error'
#   Running setup.py clean for webrtcvad
# Failed to build webrtcvad
# Installing collected packages: webrtcvad
#   Running setup.py install for webrtcvad: started
#   Running setup.py install for webrtcvad: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [9 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-39
#       copying webrtcvad.py -> build\lib.win-amd64-cpython-39
#       running build_ext
#       building '_webrtcvad' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for webrtcvad
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for webrtcvad did not run successfully.
#   │ exit code: 1
#   ╰─> [11 lines of output]
#       running install
#       C:\Users\mario\anaconda3\envs\audioprocess\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-39
#       copying webrtcvad.py -> build\lib.win-amd64-cpython-39
#       running build_ext
#       building '_webrtcvad' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> webrtcvad
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import webrtcvad
vad = webrtcvad.Vad()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15992/3401674230.py in <module>
# ----> 1 import webrtcvad
#       2 vad = webrtcvad.Vad()
#
# ModuleNotFoundError: No module named 'webrtcvad'

# %%
vad.set_mode(1)

# %%
import wave
import webrtcvad
# Initialize a vad object
audioFile = wave.open('cero_1_1.wav')
framesAudio = audioFile.readframes(800)
#print(fraud.frames)

vad = webrtcvad.Vad()
# Run the VAD on 10 ms of silence and 16000 sampling rate 
sample_rate = 16000
frame_duration = 10  # in ms
for f in framesAudio :
    # Detecting speech
    final_frame = f.to_bytes(2,"big")* int(sample_rate * frame_duration / 1000)

    print(f'Contains speech: {vad.is_speech(final_frame, sample_rate)}')

# %%
# !pip install pyannote.audio
# Out:
# Collecting pyannote.audio
#   Downloading pyannote.audio-2.1.1-py2.py3-none-any.whl (390 kB)
#      -------------------------------------- 390.7/390.7 kB 2.7 MB/s eta 0:00:00
# Collecting hmmlearn<0.3,>=0.2.7
#   Downloading hmmlearn-0.2.8-cp39-cp39-win_amd64.whl (110 kB)
#      ---------------------------------------- 110.1/110.1 kB ? eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.8.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pyannote.audio) (0.11.1)
# Collecting pyannote.metrics<4.0,>=3.2
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#      ---------------------------------------- 51.4/51.4 kB ? eta 0:00:00
# Collecting pytorch-metric-learning<2.0,>=1.0.0
#   Downloading pytorch_metric_learning-1.6.3-py3-none-any.whl (111 kB)
#      ---------------------------------------- 111.4/111.4 kB ? eta 0:00:00
# Collecting semver<3.0,>=2.10.2
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pyannote.audio) (4.3.0)
# Collecting soundfile<0.11,>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-win_amd64.whl (689 kB)
#      ------------------------------------- 689.4/689.4 kB 21.9 MB/s eta 0:00:00
# Collecting omegaconf<3.0,>=2.1
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ---------------------------------------- 79.3/79.3 kB ? eta 0:00:00
# Collecting backports.cached-property
#   Downloading backports.cached_property-1.0.2-py3-none-any.whl (6.1 kB)
# Collecting speechbrain<0.6,>=0.5.12
#   Downloading speechbrain-0.5.13-py3-none-any.whl (498 kB)
#      ------------------------------------- 499.0/499.0 kB 30.5 MB/s eta 0:00:00
# Collecting pyannote.core<5.0,>=4.4
#   Downloading pyannote.core-4.5-py3-none-any.whl (60 kB)
#      ---------------------------------------- 60.5/60.5 kB ? eta 0:00:00
# Collecting einops<0.4.0,>=0.3
#   Downloading einops-0.3.2-py3-none-any.whl (25 kB)
# Collecting singledispatchmethod
#   Downloading singledispatchmethod-1.0-py2.py3-none-any.whl (4.7 kB)
# Collecting pyannote.database<5.0,>=4.1.1
#   Downloading pyannote.database-4.1.3-py3-none-any.whl (41 kB)
#      ---------------------------------------- 41.6/41.6 kB ? eta 0:00:00
# Collecting torch>=1.9
#   Downloading torch-1.13.0-cp39-cp39-win_amd64.whl (167.2 MB)
#      ------------------------------------- 167.2/167.2 MB 14.9 MB/s eta 0:00:00
# Collecting asteroid-filterbanks<0.5,>=0.4
#   Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: networkx<3.0,>=2.6 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pyannote.audio) (2.8.4)
# Collecting pyannote.pipeline<3.0,>=2.3
#   Downloading pyannote.pipeline-2.3-py3-none-any.whl (30 kB)
# Collecting torchaudio<1.0,>=0.10
#   Downloading torchaudio-0.13.0-cp39-cp39-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 43.6 MB/s eta 0:00:00
# Collecting torchmetrics<1.0,>=0.6
#   Downloading torchmetrics-0.11.0-py3-none-any.whl (512 kB)
#      ------------------------------------- 512.4/512.4 kB 31.4 MB/s eta 0:00:00
# Collecting pytorch-lightning<1.7,>=1.5.4
#   Downloading pytorch_lightning-1.6.5-py3-none-any.whl (585 kB)
#      ------------------------------------- 585.9/585.9 kB 38.4 MB/s eta 0:00:00
# Collecting torch-audiomentations>=0.11.0
#   Downloading torch_audiomentations-0.11.0-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.9/47.9 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from asteroid-filterbanks<0.5,>=0.4->pyannote.audio) (1.21.5)
# Requirement already satisfied: scipy>=0.19 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from hmmlearn<0.3,>=0.2.7->pyannote.audio) (1.9.3)
# Requirement already satisfied: scikit-learn>=0.16 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from hmmlearn<0.3,>=0.2.7->pyannote.audio) (1.1.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from huggingface-hub>=0.8.1->pyannote.audio) (6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from huggingface-hub>=0.8.1->pyannote.audio) (21.3)
# Requirement already satisfied: tqdm in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from huggingface-hub>=0.8.1->pyannote.audio) (4.64.1)
# Requirement already satisfied: filelock in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from huggingface-hub>=0.8.1->pyannote.audio) (3.6.0)
# Requirement already satisfied: requests in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from huggingface-hub>=0.8.1->pyannote.audio) (2.28.1)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ---------------------------------------- 117.0/117.0 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: sortedcontainers>=2.0.4 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pyannote.core<5.0,>=4.4->pyannote.audio) (2.4.0)
# Collecting simplejson>=3.8.1
#   Downloading simplejson-3.18.0-cp39-cp39-win_amd64.whl (76 kB)
#      ---------------------------------------- 76.6/76.6 kB 4.4 MB/s eta 0:00:00
# Collecting typer[all]>=0.2.1
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pandas>=0.19 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pyannote.database<5.0,>=4.1.1->pyannote.audio) (1.4.4)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pyannote.metrics<4.0,>=3.2->pyannote.audio) (0.8.10)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pyannote.metrics<4.0,>=3.2->pyannote.audio) (3.5.3)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: sympy>=1.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pyannote.metrics<4.0,>=3.2->pyannote.audio) (1.10.1)
# Collecting optuna>=1.4
#   Downloading optuna-3.0.4-py3-none-any.whl (348 kB)
#      ------------------------------------- 348.5/348.5 kB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (2022.10.0)
# Requirement already satisfied: tensorboard>=2.2.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (2.10.1)
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: protobuf<=3.20.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (3.19.6)
# Collecting torchvision
#   Downloading torchvision-0.14.0-cp39-cp39-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 67.9 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from soundfile<0.11,>=0.10.2->pyannote.audio) (1.15.1)
# Collecting hyperpyyaml
#   Downloading HyperPyYAML-1.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: joblib in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from speechbrain<0.6,>=0.5.12->pyannote.audio) (1.1.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 70.2 MB/s eta 0:00:00
# Collecting julius<0.3,>=0.2.3
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ---------------------------------------- 59.6/59.6 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: librosa>=0.6.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from torch-audiomentations>=0.11.0->pyannote.audio) (0.9.2)
# Collecting torch-pitch-shift>=1.2.2
#   Downloading torch_pitch_shift-1.2.2-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: pycparser in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from cffi>=1.0->soundfile<0.11,>=0.10.2->pyannote.audio) (2.21)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.8.3-cp39-cp39-win_amd64.whl (323 kB)
#      ------------------------------------- 323.5/323.5 kB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: audioread>=2.1.9 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (3.0.0)
# Requirement already satisfied: pooch>=1.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (1.6.0)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (0.4.2)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (5.1.1)
# Requirement already satisfied: numba>=0.45.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (0.56.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio) (9.2.0)
# Collecting cliff
#   Downloading cliff-4.1.0-py3-none-any.whl (81 kB)
#      ---------------------------------------- 81.0/81.0 kB 4.4 MB/s eta 0:00:00
# Collecting alembic>=1.5.0
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
#      ---------------------------------------- 209.8/209.8 kB ? eta 0:00:00
# Requirement already satisfied: importlib-metadata<5.0.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from optuna>=1.4->pyannote.pipeline<3.0,>=2.3->pyannote.audio) (4.11.3)
# Collecting scipy>=0.19
#   Downloading scipy-1.8.1-cp39-cp39-win_amd64.whl (36.9 MB)
#      --------------------------------------- 36.9/36.9 MB 43.5 MB/s eta 0:00:00
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from optuna>=1.4->pyannote.pipeline<3.0,>=2.3->pyannote.audio) (1.4.39)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pandas>=0.19->pyannote.database<5.0,>=4.1.1->pyannote.audio) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from scikit-learn>=0.16->hmmlearn<0.3,>=0.2.7->pyannote.audio) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from sympy>=1.1->pyannote.metrics<4.0,>=3.2->pyannote.audio) (1.2.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (65.6.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (0.6.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (1.3.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (1.50.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (2.14.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from requests->huggingface-hub>=0.8.1->pyannote.audio) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from requests->huggingface-hub>=0.8.1->pyannote.audio) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from requests->huggingface-hub>=0.8.1->pyannote.audio) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from requests->huggingface-hub>=0.8.1->pyannote.audio) (2.0.4)
# Collecting primePy>=1.3
#   Downloading primePy-1.3-py3-none-any.whl (4.0 kB)
# Requirement already satisfied: colorama in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from tqdm->huggingface-hub>=0.8.1->pyannote.audio) (0.4.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from typer[all]>=0.2.1->pyannote.database<5.0,>=4.1.1->pyannote.audio) (8.0.4)
# Collecting shellingham<2.0.0,>=1.3.0
#   Downloading shellingham-1.5.0-py2.py3-none-any.whl (9.3 kB)
# Collecting rich<13.0.0,>=10.11.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ------------------------------------- 237.5/237.5 kB 14.2 MB/s eta 0:00:00
# Collecting ruamel.yaml>=0.17.8
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ---------------------------------------- 109.5/109.5 kB ? eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.3-cp39-cp39-win_amd64.whl (28 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-win_amd64.whl (34 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-win_amd64.whl (56 kB)
#      ---------------------------------------- 56.8/56.8 kB 3.1 MB/s eta 0:00:00
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.7/78.7 kB ? eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (5.2.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from importlib-metadata<5.0.0->optuna>=1.4->pyannote.pipeline<3.0,>=2.3->pyannote.audio) (3.8.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from numba>=0.45.1->librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (0.39.1)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pooch>=1.0->librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (1.4.4)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from rich<13.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database<5.0,>=4.1.1->pyannote.audio) (2.11.2)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ---------------------------------------- 51.1/51.1 kB 2.7 MB/s eta 0:00:00
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp39-cp39-win_amd64.whl (118 kB)
#      ---------------------------------------- 118.4/118.4 kB ? eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from sqlalchemy>=1.3.0->optuna>=1.4->pyannote.pipeline<3.0,>=2.3->pyannote.audio) (1.1.1)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.2-py3-none-any.whl (147 kB)
#      -------------------------------------- 147.1/147.1 kB 8.6 MB/s eta 0:00:00
# Collecting PrettyTable>=0.7.2
#   Downloading prettytable-3.5.0-py3-none-any.whl (26 kB)
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.1-py3-none-any.whl (29 kB)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-4.1.1-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.0/50.0 kB ? eta 0:00:00
# Requirement already satisfied: wcwidth>=0.1.7 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from cmd2>=1.0.0->cliff->optuna>=1.4->pyannote.pipeline<3.0,>=2.3->pyannote.audio) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyreadline3
#   Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.2/95.2 kB ? eta 0:00:00
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio) (3.2.2)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.11.0-py2.py3-none-any.whl (112 kB)
#      ---------------------------------------- 112.6/112.6 kB ? eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\mario\anaconda3\envs\entornogpu\lib\site-packages (from Mako->alembic>=1.5.0->optuna>=1.4->pyannote.pipeline<3.0,>=2.3->pyannote.audio) (2.1.1)
# Building wheels for collected packages: antlr4-python3-runtime, docopt, julius, pyperclip
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144578 sha256=8741d5a042518f667c2606761bfb358a3f52d479055b7370fa4674adc1b6ef71
#   Stored in directory: c:\users\mario\appdata\local\pip\cache\wheels\a7\72\3e\7d4bb4df2f34e8a15d0d764bb98e7ca19a765483710646a8b3
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13775 sha256=b67bcffbe46dc085c801a124d57747e064cb6169ab80efcba5702645b5274360
#   Stored in directory: c:\users\mario\appdata\local\pip\cache\wheels\4e\29\5e\e5f6f558e24e0d70f6808e3e8fdaf2c04ff597233098afc550
#   Building wheel for julius (setup.py): started
#   Building wheel for julius (setup.py): finished with status 'done'
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21925 sha256=ca7b1a1b704f663ad063059e5ab9b475d2172095bae2dd4d3718aa2a079e52ce
#   Stored in directory: c:\users\mario\appdata\local\pip\cache\wheels\01\6d\63\79ac002e0f7da61abf3fad9db8eeb28519ffce4fe9d72fd5e6
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=9b471e2bce9054bca1cdac8813e179b2351f4d55cdc9a6527b78c63d5fdfd107
#   Stored in directory: c:\users\mario\appdata\local\pip\cache\wheels\23\12\dd\067d543d895c9036459c68b02a9dcd66c7aad675ef90cbd3ab
# Successfully built antlr4-python3-runtime docopt julius pyperclip
# Installing collected packages: singledispatchmethod, sentencepiece, pyreadline3, pyperclip, primePy, einops, docopt, commonmark, antlr4-python3-runtime, torch, simplejson, shellingham, semver, scipy, ruamel.yaml.clib, rich, pyDeprecate, PrettyTable, pbr, omegaconf, multidict, Mako, frozenlist, colorlog, cmd2, cmaes, backports.cached-property, autopage, async-timeout, yarl, typer, torchvision, torchmetrics, torchaudio, stevedore, soundfile, ruamel.yaml, pyannote.core, julius, asteroid-filterbanks, alembic, aiosignal, torch-pitch-shift, pytorch-metric-learning, hyperpyyaml, hmmlearn, cliff, aiohttp, torch-audiomentations, speechbrain, pyannote.database, optuna, pytorch-lightning, pyannote.pipeline, pyannote.metrics, pyannote.audio
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Uninstalling scipy-1.9.3:
#       Successfully uninstalled scipy-1.9.3
#   Attempting uninstall: soundfile
#     Found existing installation: soundfile 0.11.0
#     Uninstalling soundfile-0.11.0:
#       Successfully uninstalled soundfile-0.11.0
# Successfully installed Mako-1.2.4 PrettyTable-3.5.0 aiohttp-3.8.3 aiosignal-1.3.1 alembic-1.8.1 antlr4-python3-runtime-4.9.3 asteroid-filterbanks-0.4.0 async-timeout-4.0.2 autopage-0.5.1 backports.cached-property-1.0.2 cliff-4.1.0 cmaes-0.9.0 cmd2-2.4.2 colorlog-6.7.0 commonmark-0.9.1 docopt-0.6.2 einops-0.3.2 frozenlist-1.3.3 hmmlearn-0.2.8 hyperpyyaml-1.1.0 julius-0.2.7 multidict-6.0.3 omegaconf-2.2.3 optuna-3.0.4 pbr-5.11.0 primePy-1.3 pyDeprecate-0.3.2 pyannote.audio-2.1.1 pyannote.core-4.5 pyannote.database-4.1.3 pyannote.metrics-3.2.1 pyannote.pipeline-2.3 pyperclip-1.8.2 pyreadline3-3.4.1 pytorch-lightning-1.6.5 pytorch-metric-learning-1.6.3 rich-12.6.0 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.7 scipy-1.8.1 semver-2.13.0 sentencepiece-0.1.97 shellingham-1.5.0 simplejson-3.18.0 singledispatchmethod-1.0 soundfile-0.10.3.post1 speechbrain-0.5.13 stevedore-4.1.1 torch-1.13.0 torch-audiomentations-0.11.0 torch-pitch-shift-1.2.2 torchaudio-0.13.0 torchmetrics-0.11.0 torchvision-0.14.0 typer-0.7.0 yarl-1.8.2

# %%
from pyannote.audio import Pipeline
pipeline = Pipeline.from_pretrained("pyannote/voice-activity-detection",
                                    use_auth_token="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")
output = pipeline("audio.wav")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\Users\mario\anaconda3\envs\entornoGPU\lib\site-packages\huggingface_hub\utils\_errors.py in hf_raise_for_status(response, endpoint_name)
#     238     try:
# --> 239         response.raise_for_status()
#     240     except HTTPError as e:
#
# c:\Users\mario\anaconda3\envs\entornoGPU\lib\site-packages\requests\models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/pyannote/voice-activity-detection/resolve/main/config.yaml
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22720\259364896.py in <module>
#       1 from pyannote.audio import Pipeline
# ----> 2 pipeline = Pipeline.from_pretrained("pyannote/voice-activity-detection",
#       3                                     use_auth_token="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")
#       4 output = pipeline("audio.wav")
#
# c:\Users\mario\anaconda3\envs\entornoGPU\lib\site-packages\pyannote\audio\core\pipeline.py in from_pretrained(cls, checkpoint_path, hparams_file, use_auth_token, cache_dir)
#      81
#      82             try:
# ---> 83                 config_yml = hf_hub_download(
#      84                     model_id,
#      85                     PIPELINE_PARAMS_NAME,
#
# c:\Users\mario\anaconda3\envs\entornoGPU\lib\site-packages\huggingface_hub\utils\_validators.py in _inner_fn(*args, **kwargs)
#     122             )
#     123
# --> 124         return fn(*args, **kwargs)
#     125
#     126     return _inner_fn  # type: ignore
#
# c:\Users\mario\anaconda3\envs\entornoGPU\lib\site-packages\huggingface_hub\file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1065         try:
#    1066             try:
# -> 1067                 metadata = get_hf_file_metadata(
#    1068                     url=url,
#    1069                     token=token,
#
# c:\Users\mario\anaconda3\envs\entornoGPU\lib\site-packages\huggingface_hub\utils\_validators.py in _inner_fn(*args, **kwargs)
#     122             )
#     123
# --> 124         return fn(*args, **kwargs)
#     125
#     126     return _inner_fn  # type: ignore
#
# c:\Users\mario\anaconda3\envs\entornoGPU\lib\site-packages\huggingface_hub\file_download.py in get_hf_file_metadata(url, token, proxies, timeout)
#    1374         timeout=timeout,
#    1375     )
# -> 1376     hf_raise_for_status(r)
#    1377
#    1378     # Return
#
# c:\Users\mario\anaconda3\envs\entornoGPU\lib\site-packages\huggingface_hub\utils\_errors.py in hf_raise_for_status(response, endpoint_name)
#     278         # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     279         # as well (request id and/or server error message)
# --> 280         raise HfHubHTTPError(str(e), response=response) from e
#     281
#     282
#
# HfHubHTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/pyannote/voice-activity-detection/resolve/main/config.yaml (Request ID: Root=1-638b1add-000bb17a5f39eaf932b4965c)
#
# Access to model pyannote/voice-activity-detection is restricted and you are not in the authorized list. Visit https://huggingface.co/pyannote/voice-activity-detection to ask for access.
